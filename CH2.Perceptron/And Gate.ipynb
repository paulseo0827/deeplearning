# %% [markdown]
# 1) 퍼셉트론 (인공 뉴런 혹은 단순 퍼셉트론)
#
# 다수의 신호를 입력으로 받아 하나의 신호를 출력
#
# 하단 그림은 입력 여러개의 신호를 받은 퍼셉트론의 예로 x1~xi는 입력 신호, out는 출력 신호, w1~wi는 가중치 (w = weight) 를 뜻 함

# %%
from IPython.display import Image
Image(filename='perceptron.PNG')

# %% [markdown]
# [AND 게이트 진리표]
#
# | X1 | X2 |  Y  |
# | :--: | :--: | :--: |
# | 0	 | 0  | 0  |
# | 1	 | 0  | 0  |
# | 0	 | 1  | 0  |
# | 1	 | 1  | 1  |

# %%
import numpy as np

# %%
def AND(x1, x2):
    w1, w2, theta = 0.5, 0.5, 0.7
    tmp = x1*w1 + x2*w2
    if tmp <= theta:
        return 0
    elif tmp > theta:
        return 1

# %%
print ('AND(0, 0) => ', AND(0, 0))
# Out:
# AND(0, 0) =>  0

# %%
print ('AND(1, 0) => ', AND(1, 0))
# Out:
# AND(1, 0) =>  0

# %%
print ('AND(0, 1) => ', AND(0, 1))
# Out:
# AND(0, 1) =>  0

# %%
print ('AND(1, 1) => ', AND(1, 1))
# Out:
# AND(1, 1) =>  1
